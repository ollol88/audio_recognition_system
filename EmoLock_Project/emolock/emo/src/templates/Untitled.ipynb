# %%
import pandas as pd
df=pd.read_csv("vector")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-88ba4f6e9145> in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("vector")
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import numpy as np
import requests

x=np.array([0, 0, 0.5])
sr=16000
def record_processing(audio_file):
    #load file as numpy array
    #x, sr = lr.load(audio_file, sr=16000)
    #define scaler
    from sklearn.preprocessing import RobustScaler
    scaler = RobustScaler(with_centering=False)
    #### new record preprocessing ####
    #load speech recognition model
    url1 = "http://192.168.9.221:8501/v1/models/model:predict"
    #load speech recognition model
    url2 = "http://192.168.9.221:8502/v1/models/model:predict"
    #get speech probabilities from new record
    new_speech_proba = []
    audio_file= scaler.fit_transform(x[:, np.newaxis])
    req_audio=requests.post(url2, json={"instances": [x.tolist()]}).json()
    new_speech_proba.append(np.array(req_audio["predictions"][0]))
    #create extended audio and probabilities files
    audio_extend_new = []
    proba_extend_new = []
    a, sra = lr.load(audio_file, sr=16000)
    b=new_speech_proba[0]
    x1=np.repeat(a,len(b))
    y1=np.repeat(b,len(a))
    audio_extend_new.append(x1)
    proba_extend_new.append(y1)
    #create compressed audio (filtered with probability of speech > treshold and take unique values)
    treshold=0.5
    audio_compressed_new = audio_extend_new[0][proba_extend_new[0] > treshold]
    audio_compressed_new=np.unique(audio_compressed_new)
    #get cleaned embeddings from new record
    X_new_speaker=[]
    audio_compressed_new= scaler.fit_transform(audio_compressed_new[:, np.newaxis])
    req_audio=requests.post(url1, json={"instances": [audio_compressed_new.tolist()]}).json()
    X_new_speaker.append(np.array(req_audio["predictions"][0]))
    X_new_speaker=X_new_speaker[0]
    return X_new_speaker

record_processing(x)
# Out:
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# C:\Users\user\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\Users\user\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...
